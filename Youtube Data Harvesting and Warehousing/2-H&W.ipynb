# %%
# MongoDB setup
import pymongo
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://vinovv03:vino1234@cluster1.evmfdz1.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(uri)

try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

mydb = client.youtube  
myth = mydb.harvest
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
vp = myth.find_one()
vp
# Out:
# {'_id': ObjectId('65167e5e11d35dda38dd9a32'),
#  'channel details': [{'channel_name': 'Wisdom Insights',
#    'channel_id': 'UCSTkDAzusiM1dumQ-znMtsw',
#    'subscription_count': '123000',
#    'channel_views': '6760104',
#    'channel_description': 'Welcome,\n"Wisdom Insights" is a YouTube channel dedicated to providing insightful stories and motivational quotes from famous people and authors. We take the time to research and analyze each story to provide valuable thought-provoking insights to help you improve your life. Our channel covers a wide range of topics including motivational story, success story, leadership, relationship story, buddha story, and more. Our goal is to inspire and empower you to become the best version of yourself.\n\nFor Business/Sponsorship (Contact): pratapofficialpk@gmail.com \n',
#    'video_count': '98'}],
#  'playlist details': [{'channel_id': 'UCSTkDAzusiM1dumQ-znMtsw',
#    'playlist_id': 'PLLTddTKW_OUOVoGSiF0DK1od0mCpDdgnx',
# ...

# %%
cdl = []
cd = vp.get("channel details", [])  
for ic in cd:
    cdl.append(tuple(ic.values()))
cdt = tuple(cdl)
print(cdt)
# Out:
# (('Wisdom Insights', 'UCSTkDAzusiM1dumQ-znMtsw', '123000', '6760104', 'Welcome,\n"Wisdom Insights" is a YouTube channel dedicated to providing insightful stories and motivational quotes from famous people and authors. We take the time to research and analyze each story to provide valuable thought-provoking insights to help you improve your life. Our channel covers a wide range of topics including motivational story, success story, leadership, relationship story, buddha story, and more. Our goal is to inspire and empower you to become the best version of yourself.\n\nFor Business/Sponsorship (Contact): pratapofficialpk@gmail.com \n', '98'),)

# %%
pdl = []
pd = vp.get("playlist details", [])  
for ip in pd:
    pdl.append(tuple(ip.values()))
pdt = tuple(pdl)

print(pdt)
# Out:
# (('UCSTkDAzusiM1dumQ-znMtsw', 'PLLTddTKW_OUOVoGSiF0DK1od0mCpDdgnx', '2023-04-12T04:04:42Z', 'Powerful Motivational Video', 4), ('UCSTkDAzusiM1dumQ-znMtsw', 'PLLTddTKW_OUP-r0gdKI-qYe-4lcjoAJVb', '2023-02-18T04:55:21Z', 'Life Changing Story', 94), ('UCSTkDAzusiM1dumQ-znMtsw', 'PLLTddTKW_OUMAmehK2IUGD9PhZr3LtwQo', '2023-02-13T07:59:40Z', 'Albert Einstein Quotes', 1))

# %%
vdl = []
vd = vp.get("video details", [])  
for iv in vd:
    vdl.append(tuple(iv.values()))
vdt = tuple(vdl)
print(vdt)
# Out:
# (('PLLTddTKW_OUOVoGSiF0DK1od0mCpDdgnx', 'ku7d1AJSVdc', 'UCSTkDAzusiM1dumQ-znMtsw', 'How to Overcome Fear | Face Your Fear | Gautam Buddha Motivational Story', "How to Overcome Fear | Face Your Fear | Gautam Buddha Motivational Story\n\nIf you've ever struggled with fear, you're not alone. Everyone experiences fear at some point in their lives, but that doesn't mean you have to let it control you. In this video, you'll discover Gautam Buddha's powerful technique for overcoming fear. By unlocking this secret, you'll be able to say goodbye to fear forever and live a fearless life. Join us as we explore Gautam Buddha's story on fear and learn how you can apply his wisdom to your own life.\n\n#faceyourfear #overcomefear #gautambuddha #motivation #gautambuddha #motivationalstory \n\nDon't forget to subscribe: @wisdom_insights \n\nDisclaimer: The materials and the information available at this channel are intended for general and educational purposes only. All the videos, pictures and music
# ...

# %%
cmdl = []
cmd = vp.get("comments details", [])  
for icm in cmd:
    cmdl.append(tuple(icm.values()))
cmdt = tuple(cmdl)
print(cmdt)
# Out:
# (('UCSTkDAzusiM1dumQ-znMtsw', '457BMuSkgto', 'Ugy4qSY8BWc0NzWClD94AaABAg', 'This story was written by ChatGPT', 0, '2023-09-23T09:46:59Z', 'Fajana Anthony'), ('UCSTkDAzusiM1dumQ-znMtsw', '457BMuSkgto', 'UgyE3SB5fgSzkrVkcTl4AaABAg', '&quot;Keep your face always toward the sunshine—and shadows will fall behind you.&quot; - Walt Whitman', 1, '2023-09-20T11:41:39Z', 'Wisdom Narratives'), ('UCSTkDAzusiM1dumQ-znMtsw', '457BMuSkgto', 'UgwLk__CLmYlOuhyHph4AaABAg', 'Chotu, don&#39;t look up😂<br><br>Just listen', 1, '2023-09-19T09:35:01Z', 'Sridhar Nimmakayala'), ('UCSTkDAzusiM1dumQ-znMtsw', '457BMuSkgto', 'UgyC4s6CfUlHj6LinHF4AaABAg', 'Human mind.hecis creature mind', 0, '2023-09-19T04:15:44Z', '没心没肺'), ('UCSTkDAzusiM1dumQ-znMtsw', '457BMuSkgto', 'Ugxtd65xATUGqYKsK8V4AaABAg', 'Alot of beast and asshole non proof wrong methods.stick to my methods better', 0, '2023-09-19T04:11:03Z', '没心没肺'), ('UCSTkDAzusiM1dumQ-znMtsw', '457BMuSkgto', 'UgxP9HEq3rf6ezoxHhN4AaABAg', '❤🎉THANK YOU SO VERY VERY MUCH
# ...

# %%
# MySQL setup
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="abc")
#     autocommit= True
print(mydb)
mycursor=mydb.cursor(buffered=True)

# %%
mycursor.execute("""
    CREATE TABLE channel (
        channel_name VARCHAR(255),
        channel_id VARCHAR(255) PRIMARY KEY,
        subscription_count INT,
        channel_views INT,
        channel_description TEXT,
        video_count INT
    )
    """)

# %%
# to insert channel data into table 
sql_c = """INSERT IGNORE INTO channel(channel_name,
        channel_id,
        subscription_count,
        channel_views,
        channel_description,
        video_count) VALUES (%s, %s, %s, %s, %s, %s)"""

mycursor.executemany(sql_c, cdt)

mydb.commit()

# %%
mycursor.execute("""
    CREATE TABLE playlist (
        channel_id VARCHAR(255),
        playlist_id VARCHAR(255) PRIMARY KEY,
        publishedAt DATETIME,
        playlist_title VARCHAR(255),
        playlist_video_count INT
    )
    """)

# %%
# to insert playlist data into table 
sql_p = """INSERT IGNORE INTO playlist(channel_id ,
        playlist_id ,
        publishedAt ,
        playlist_title,
        playlist_video_count) VALUES (%s, %s, %s, %s, %s)"""

mycursor.executemany(sql_p, pdt)

mydb.commit()

# %%
mycursor.execute("""
    CREATE TABLE video (playlist_id VARCHAR(255),
        video_id VARCHAR(255) PRIMARY KEY,
        channel_id VARCHAR(255),
        video_title VARCHAR(255),
        video_description TEXT,
        video_published_date DATETIME,
        video_duration VARCHAR(255),
        video_view_count INT,
        video_like_count INT,
        video_dislike_count INT,
        video_favorite_count INT,
        video_comment_count INT,
        video_thumbnail VARCHAR(255))
    """)

# %%
# to insert video data into table 
sql_v = """INSERT IGNORE INTO video(playlist_id ,
        video_id ,
        channel_id,
        video_title ,
        video_description ,
        video_published_date ,
        video_duration,
        video_view_count,
        video_like_count,
        video_dislike_count,
        video_favorite_count,
        video_comment_count,
        video_thumbnail) VALUES (%s, %s, %s, %s, %s,%s,%s,%s,%s,%s,%s,%s,%s)"""

mycursor.executemany(sql_v, vdt)

mydb.commit()

# %%
mycursor.execute("""
    CREATE TABLE comments (channel_id VARCHAR(255),
        video_id VARCHAR(255),
        comment_id VARCHAR(255) PRIMARY KEY,
        comment_text TEXT,
        comment_likes INT,
        comment_published_date DATETIME,
        comment_author VARCHAR(255))
   """)

# %%
sql_cm = """INSERT IGNORE INTO comments(channel_id,
        video_id,
        comment_id,
        comment_text,
        comment_likes,
        comment_published_date,
        comment_author) VALUES (%s, %s, %s, %s, %s, %s, %s)"""

mycursor.executemany(sql_cm, cmdt)

mydb.commit()

# %%
import mysql.connector

def insert_data_into_mysql(channel_id):
    # Your existing code for fetching data here...
    cd = vp.get("channel details", [])  
    pd = vp.get("playlist details", [])  
    vd = vp.get("video details", [])  
    cmd = vp.get("comments details", [])  

    cdt_list = [tuple(channel.values()) for channel in cd]
    pdt_list = [tuple(playlist.values()) for playlist in pd]
    vdt_list = [tuple(video.values()) for video in vd]
    cmdt_list = [tuple(comments.values()) for comments in cmd]

    cdt = tuple(cdt_list)
    pdt = tuple(pdt_list)
    vdt = tuple(vdt_list)
    cmdt = tuple(cmdt_list)

    # Insert data into MySQL tables here...
    # Use your SQL queries and mycursor.executemany() for each table
    # Example:
    mycursor.executemany(sql_c, cdt)
    mycursor.executemany(sql_p, pdt)
    mycursor.executemany(sql_v, vdt)
    mycursor.executemany(sql_cm, cmdt)

#     Commit changes to the database
    mydb.commit()

# Example usage:
channel_id = "UCLnRd3yCnEjVxiCaZs8RQ1Q"
insert_data_into_mysql(channel_id)
